# %% [markdown]
# <a href="https://colab.research.google.com/github/sanketajena1/Python-training-SRU/blob/main/Python_Workshp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day-1

# %%
x = 5
y ="John"
z=3.0
print (x)
print (y)
print (z)
# Out:
# 5
# John
# 3.0

# %%
print (type(x))
print (y)
print (z)
# Out:
# <class 'int'>
# John
# 3.0

# %%
y1=2
print(y1)
print(type(y1))
y2=float(y1)
print(y2)
print(type(y2))
y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %%
y1=int(2)
y2=float(2)
y3=str(2)
print(y1)
print(y2)
print(y3)
print(type(y1))
print(type(y2))
print(type(y3))
# Out:
# 2
# 2.0
# 2
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
myname= "Sanketa"
my_dep="Physics"
_my_University= "SRU"
myloC="warangal"
MYDEP2="Phy"
print(myname)
print(my_dep)
print(_my_University)
print(myloC)
print(MYDEP2)
# Out:
# Sanketa
# Physics
# SRU
# warangal
# Phy

# %%
a=input("enter value of a")
b=input("enter value of b")
a=int(a)
b=int(b)
print(a+b)
print("subtraction=",a-b)
print("multiplication=",a*b)
print("division=",a/b)
print("floor division=",a//b)
print("Rem=",a%b)
print("exponent=",a**b)
# Out:
# enter value of a10
# enter value of b20
# 30
# subtraction= -10
# multiplication= 200
# division= 0.5
# floor division= 0
# Rem= 10
# exponent= 100000000000000000000

# %%
Day 2

# %% [markdown]
# Day-2

# %%
a=input("enter First name")
b=input("enter last name")
print("Arithmatic operation on string")
Full_Name=a+b #string Concattenation
print("Full Name=",Full_Name)
repeat_name=Full_Name*2
print("Repeat_name=",repeat_name)
# Out:
# enter First nameSanketa
# enter last nameJena
# Arithmatic operation on string
# Full Name= SanketaJena
# Repeat_name= SanketaJenaSanketaJena

# %%
a=input("enter First name")
b=input("enter last name")
print("Arithmatic operation on string")
Full_Name=a+b+" " #string Concattenation
print("Full Name=",Full_Name)
repeat_name=Full_Name*2
print("Repeat_name=",repeat_name)
# Out:
# enter First nameSanketa
# enter last nameJena
# Arithmatic operation on string
# Full Name= SanketaJena
# Repeat_name= SanketaJena SanketaJena

# %% [markdown]
# Precedence Operator

# %%
a=20
b=30
c=40
print("value1=", a+b*c)
print("value2=", (a+b)*c)
print("value3=", c/a+(b*c))
# Out:
# value1= 1220
# value2= 2000
# value3= 1202.0

# %% [markdown]
# Relational Operator

# %%
num1=20
num2=30
print("Status=",num1>num2)
print("Status=",num1<num2)
print("Status=",num1>=num2)
print("Status=",num1<=num2)
print("Status=",num1==num2)
print("Status=",num1!=num2)
# Out:
# Status= False
# Status= True
# Status= False
# Status= True
# Status= False
# Status= True

# %% [markdown]
# Logical Operators

# %%
num1=20
num2=30
num3=10
print("Status=",num1==num2 and num1==num3)
print("Status=",num1==num2 or num1==num3)
print("Status=",not(num1==num2))
# Out:
# Status= False
# Status= False
# Status= True

# %%
num1=20
num2=30
num3=20
print("Status=",num1==num2 and num1==num3)
print("Status=",num1==num2 or num1==num3)
print("Status=",not(num1==num2))
# Out:
# Status= False
# Status= True
# Status= True

# %% [markdown]
# Assignment Operator

# %%
num1=10
print("num1=", num1)
num2=num1
print("num2=", num2)
num2=20
print("num2=", num2)
num1+=num2 #num1=10+20
print("num1=", num1)
num1-=num2 #num1=30-20
print("num1=", num1)
num1*=num2 #num1=num1*num2
print("num1=", num1)
num1/=num2 #num1=num1/num2
print("num1=", num1)
num1%=num2 #num1=num1%num2
print("num1=", num1)
num1//=num2 #num1=num//num2
print("num1=", num1)
num2**=2 #num2=num2**2
print("num2=", num2)
num2**=2 #num2=num2*num2
print("num2=", num2)
# Out:
# num1= 10
# num2= 10
# num2= 20
# num1= 30
# num1= 10
# num1= 200
# num1= 10.0
# num1= 10.0
# num1= 0.0
# num2= 400
# num2= 160000

# %% [markdown]
# Membership Operator

# %%
students=["Sanketa", "Jena"]
call_attendance=("Sanketa" in students)
print("Status=",call_attendance)
call_attendance=("Sanketa" not in students)
print("Status=",call_attendance)
# Out:
# Status= True
# Status= False

# %% [markdown]
# Bitwise operator

# %%
a=10 #a=1010
b=20 #b=10100
print("a&b=",a&b)
print("a|b=",a|b)
print("a^b=",a^b)
# Out:
# a&b= 0
# a|b= 30
# a^b= 30

# %%
a=10 #a=1010
b=20 #b=10100
print("Results=", a&b)
print("Results=", a|b)
print("Results=", a^b)
print("Results=", ~a)
print("Results=", ~b)
print("Results=", ~a)
# Out:
# Results= 0
# Results= 30
# Results= 30
# Results= -11
# Results= -21
# Results= -11

# %% [markdown]
# Identity Operator (is, is not)

# %%
a=[1,2,3]
b=a
c=[1,2,3]
print("status=", a==c)
print("status=", a==b)
print("status=", b==c)
print("status=", a != b)
print("status=", a != c)
print("status=", b != c)
print("status=", a is c)
print("status=", a is b)
print("status=", b is c)
print("status=", a is not c)
print("status=", a is not b)
print("status=", b is not c)
print("status=", a is not c)
print("status=", a is not b)
print("status=", b is not c)
# Out:
# status= True
# status= True
# status= True
# status= False
# status= False
# status= False
# status= False
# status= True
# status= False
# status= True
# status= False
# status= True
# status= True
# status= False
# status= True

# %% [markdown]
# Conditional Statement

# %%
userid=["Sanketa", "vvr"]
username=input ("Input user name")
if(username in userid):
  print("user exist")
# Out:
# Input user namesanketa

# %%
#odd number check
num=input("enter number to check")
num=int(num)
if(num%2!=0):
  print(f"number {num} is odd")
# Out:
# enter number to check5
# number 5 is odd

# %%
userid=["Sanketa","Jena"]
username=input("Input user name")
if(username in userid):
  print("user exist")
else:
  print("user does not exist")
# Out:
# Input user nameAbishek
# user does not exist

# %%
#odd and even number check
num=input("enter number to check")
num=int(num)
if(num%2!=0):
  print(f"number {num} is odd")
else:
  print(f"number {num} is even")
# Out:
# enter number to check5
# number 5 is odd

# %%
marks=input("enter marks")
marks=int(marks)
print("pass") if marks>=45 else print ("fail")
# Out:
# enter marks70
# pass

# %%
marks=input("enter marks")
marks=int(marks)
if marks>=45:
  print("student pass in subject")
if marks>60:
  print("student pass in D grade")
if marks <45:
  print("student pass in C subject")
# Out:
# enter marks70
# student pass in subject
# student pass in D grade

# %%
arks=input("enter marks")
marks=int(marks)
if marks>=45:
  print("student pass in subject")
if marks>60 and marks>80:
  print("student pass in D grade")
# Out:
# enter marks90
# student pass in subject

# %% [markdown]
# Nested if statement

# %%
marks=input("enter marks")
marks=int(marks)
if marks>=45:
  print("student pass in subject")
  if marks>60:
   print("student pass in D grade")
   if marks <45:
    print("student pass in C subject")
# Out:
# enter marks90
# student pass in subject
# student pass in D grade

# %% [markdown]
# if-elif statement

# %%
marks=input("enter marks")
marks=int(marks)
if marks>=45:
  print("student pass in subject")
elif marks>60:
  print("student pass in B grade")
else:
  print("student fail in subject")

# %%
price=input("enter price per units")
units=int(units)
if unit>

# %% [markdown]
# marks=input("enter marks")
# marks=int(marks)
# if marks>=45:
#   print("student pass in subject")
# if marks>60:
#   print("student pass in D grade")
# if marks >45:
#   print("student fail in subject")
