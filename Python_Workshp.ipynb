# %% [markdown]
# <a href="https://colab.research.google.com/github/sanketajena1/Python-training-SRU/blob/main/Python_Workshp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day-1

# %%
x = 5
y ="John"
z=3.0
print (x)
print (y)
print (z)
# Out:
# 5
# John
# 3.0

# %%
print (type(x))
print (y)
print (z)
# Out:
# <class 'int'>
# John
# 3.0

# %%
y1=2
print(y1)
print(type(y1))
y2=float(y1)
print(y2)
print(type(y2))
y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %%
y1=int(2)
y2=float(2)
y3=str(2)
print(y1)
print(y2)
print(y3)
print(type(y1))
print(type(y2))
print(type(y3))
# Out:
# 2
# 2.0
# 2
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
myname= "Sanketa"
my_dep="Physics"
_my_University= "SRU"
myloC="warangal"
MYDEP2="Phy"
print(myname)
print(my_dep)
print(_my_University)
print(myloC)
print(MYDEP2)
# Out:
# Sanketa
# Physics
# SRU
# warangal
# Phy

# %%
a=input("enter value of a")
b=input("enter value of b")
a=int(a)
b=int(b)
print(a+b)
print("subtraction=",a-b)
print("multiplication=",a*b)
print("division=",a/b)
print("floor division=",a//b)
print("Rem=",a%b)
print("exponent=",a**b)
# Out:
# enter value of a10
# enter value of b20
# 30
# subtraction= -10
# multiplication= 200
# division= 0.5
# floor division= 0
# Rem= 10
# exponent= 100000000000000000000

# %%
Day 2

# %% [markdown]
# Day-2

# %%
a=input("enter First name")
b=input("enter last name")
print("Arithmatic operation on string")
Full_Name=a+b #string Concattenation
print("Full Name=",Full_Name)
repeat_name=Full_Name*2
print("Repeat_name=",repeat_name)
# Out:
# enter First nameSanketa
# enter last nameJena
# Arithmatic operation on string
# Full Name= SanketaJena
# Repeat_name= SanketaJenaSanketaJena

# %%
a=input("enter First name")
b=input("enter last name")
print("Arithmatic operation on string")
Full_Name=a+b+" " #string Concattenation
print("Full Name=",Full_Name)
repeat_name=Full_Name*2
print("Repeat_name=",repeat_name)
# Out:
# enter First nameSanketa
# enter last nameJena
# Arithmatic operation on string
# Full Name= SanketaJena
# Repeat_name= SanketaJena SanketaJena

# %% [markdown]
# Precedence Operator

# %%
a=20
b=30
c=40
print("value1=", a+b*c)
print("value2=", (a+b)*c)
print("value3=", c/a+(b*c))
# Out:
# value1= 1220
# value2= 2000
# value3= 1202.0

# %% [markdown]
# Relational Operator

# %%
num1=20
num2=30
print("Status=",num1>num2)
print("Status=",num1<num2)
print("Status=",num1>=num2)
print("Status=",num1<=num2)
print("Status=",num1==num2)
print("Status=",num1!=num2)
# Out:
# Status= False
# Status= True
# Status= False
# Status= True
# Status= False
# Status= True

# %% [markdown]
# Logical Operators

# %%
num1=20
num2=30
num3=10
print("Status=",num1==num2 and num1==num3)
print("Status=",num1==num2 or num1==num3)
print("Status=",not(num1==num2))
# Out:
# Status= False
# Status= False
# Status= True

# %%
num1=20
num2=30
num3=20
print("Status=",num1==num2 and num1==num3)
print("Status=",num1==num2 or num1==num3)
print("Status=",not(num1==num2))
# Out:
# Status= False
# Status= True
# Status= True

# %% [markdown]
# Assignment Operator

# %%
num1=10
print("num1=", num1)
num2=num1
print("num2=", num2)
num2=20
print("num2=", num2)
num1+=num2 #num1=10+20
print("num1=", num1)
num1-=num2 #num1=30-20
print("num1=", num1)
num1*=num2 #num1=num1*num2
print("num1=", num1)
num1/=num2 #num1=num1/num2
print("num1=", num1)
num1%=num2 #num1=num1%num2
print("num1=", num1)
num1//=num2 #num1=num//num2
print("num1=", num1)
num2**=2 #num2=num2**2
print("num2=", num2)
num2**=2 #num2=num2*num2
print("num2=", num2)
# Out:
# num1= 10
# num2= 10
# num2= 20
# num1= 30
# num1= 10
# num1= 200
# num1= 10.0
# num1= 10.0
# num1= 0.0
# num2= 400
# num2= 160000

# %% [markdown]
# Membership Operator

# %%
students=["Sanketa", "Jena"]
call_attendance=("Sanketa" in students)
print("Status=",call_attendance)
call_attendance=("Sanketa" not in students)
print("Status=",call_attendance)
# Out:
# Status= True
# Status= False

# %% [markdown]
# Bitwise operator

# %%
a=10 #a=1010
b=20 #b=10100
print("a&b=",a&b)
print("a|b=",a|b)
print("a^b=",a^b)
# Out:
# a&b= 0
# a|b= 30
# a^b= 30

# %%
a=10 #a=1010
b=20 #b=10100
print("Results=", a&b)
print("Results=", a|b)
print("Results=", a^b)
print("Results=", ~a)
print("Results=", ~b)
print("Results=", ~a)
# Out:
# Results= 0
# Results= 30
# Results= 30
# Results= -11
# Results= -21
# Results= -11

# %% [markdown]
# Identity Operator (is, is not)

# %%
a=[1,2,3]
b=a
c=[1,2,3]
print("status=", a==c)
print("status=", a==b)
print("status=", b==c)
print("status=", a != b)
print("status=", a != c)
print("status=", b != c)
print("status=", a is c)
print("status=", a is b)
print("status=", b is c)
print("status=", a is not c)
print("status=", a is not b)
print("status=", b is not c)
print("status=", a is not c)
print("status=", a is not b)
print("status=", b is not c)
# Out:
# status= True
# status= True
# status= True
# status= False
# status= False
# status= False
# status= False
# status= True
# status= False
# status= True
# status= False
# status= True
# status= True
# status= False
# status= True

# %% [markdown]
# Conditional Statement

# %%
userid=["Sanketa", "vvr"]
username=input ("Input user name")
if(username in userid):
  print("user exist")
# Out:
# Input user namesanketa

# %%
#odd number check
num=input("enter number to check")
num=int(num)
if(num%2!=0):
  print(f"number {num} is odd")
# Out:
# enter number to check5
# number 5 is odd

# %%
userid=["Sanketa","Jena"]
username=input("Input user name")
if(username in userid):
  print("user exist")
else:
  print("user does not exist")
# Out:
# Input user nameAbishek
# user does not exist

# %%
#odd and even number check
num=input("enter number to check")
num=int(num)
if(num%2!=0):
  print(f"number {num} is odd")
else:
  print(f"number {num} is even")
# Out:
# enter number to check5
# number 5 is odd

# %%
marks=input("enter marks")
marks=int(marks)
print("pass") if marks>=45 else print ("fail")
# Out:
# enter marks70
# pass

# %%
marks=input("enter marks")
marks=int(marks)
if marks>=45:
  print("student pass in subject")
if marks>60:
  print("student pass in D grade")
if marks <45:
  print("student pass in C subject")
# Out:
# enter marks70
# student pass in subject
# student pass in D grade

# %%
arks=input("enter marks")
marks=int(marks)
if marks>=45:
  print("student pass in subject")
if marks>60 and marks>80:
  print("student pass in D grade")
# Out:
# enter marks90
# student pass in subject

# %% [markdown]
# Nested if statement

# %%
marks=input("enter marks")
marks=int(marks)
if marks>=45:
  print("student pass in subject")
  if marks>60:
   print("student pass in D grade")
   if marks <45:
    print("student pass in C subject")
# Out:
# enter marks90
# student pass in subject
# student pass in D grade

# %% [markdown]
# if-elif statement

# %%
marks=input("enter marks")
marks=int(marks)
if marks>=45:
  print("student pass in subject")
elif marks>60:
  print("student pass in B grade")
else:
  print("student fail in subject")

# %%
costumer=input("enter costumer type")
units=input("enter units")
units=int(units)
if costumer=="residential":
  print(f"price={units*2}")
if costumer=="comercial":
  print(f"price={units*5}")
if costumer=="industrial":
  print(f"price={units*10}")
# Out:
# enter costumer typeresidential
# enter units45
# price=90

# %% [markdown]
# marks=input("enter marks")
# marks=int(marks)
# if marks>=45:
#   print("student pass in subject")
# if marks>60:
#   print("student pass in D grade")
# if marks >45:
#   print("student fail in subject")

# %% [markdown]
# Day-3 (Prompt Engingineering)

# %% [markdown]
# Write python code for calculator applivcation. No functions, two inputs will be given as inputs by user. no if-else

# %% [markdown]
# prompt:write python code for energy price calculation. Unit will be provided by users as input by user. no if-else condition. print allarithmentic operation values.
# Example: price=units*2 for residential customer
# price=units*5 for commercial customer
# price=units*for industrial customer

# %%
units_input = input("Enter the number of units consumed: ")
units = int(units_input)

# Calculate price for residential customer
price_residential = units * 2
print(f"Price for residential customer: {price_residential}")

# Calculate price for commercial customer
price_commercial = units * 5
print(f"Price for commercial customer: {price_commercial}")

# Calculate price for industrial customer (assuming a multiplier of 10 as the example was incomplete)
price_industrial = units * 10
print(f"Price for industrial customer: {price_industrial}")
# Out:
# Enter the number of units consumed: 2
# Price for residential customer: 4
# Price for commercial customer: 10
# Price for industrial customer: 20

# %% [markdown]
# write python code for calculator application. No functions. two inputs will be given as inputs by user. no if-else conditions, print all arithmetic operation values

# %%
num1_str = input("Enter the first number: ")
num2_str = input("Enter the second number: ")

num1 = float(num1_str)
num2 = float(num2_str)

print(f"Addition: {num1 + num2}")
print(f"Subtraction: {num1 - num2}")
print(f"Multiplication: {num1 * num2}")
print(f"Division: {num1 / num2}")
print(f"Floor Division: {num1 // num2}")
print(f"Modulo: {num1 % num2}")
print(f"Exponentiation: {num1 ** num2}")
# Out:
# Enter the first number: 2
# Enter the second number: 4
# Addition: 6.0
# Subtraction: -2.0
# Multiplication: 8.0
# Division: 0.5
# Floor Division: 0.0
# Modulo: 2.0
# Exponentiation: 16.0

# %% [markdown]
# Day-4

# %% [markdown]
# How we will execute same statement multiple times

# %%
print("Hello,Sanketa")
print("Hello,Sanketa")
print("Hello,Sanketa")
print("Hello,Sanketa")
print("Hello,Sanketa")
# Out:
# Hello,Sanketa
# Hello,Sanketa
# Hello,Sanketa
# Hello,Sanketa
# Hello,Sanketa

# %% [markdown]
# While loop

# %%
i=0
while(i<=5):
 print("Hello,Sanketa")
 i=i+1
# Out:
# Hello,Sanketa
# Hello,Sanketa
# Hello,Sanketa
# Hello,Sanketa
# Hello,Sanketa
# Hello,Sanketa

# %% [markdown]
# Print number table

# %%
num=input("enter the number you want to print")
num=int(num)
i=0
while(i<=10):
  print(f"{num}*{i}={num*i}")
  i=i+1
# Out:
# enter the number you want to print2
# 2*0=0
# 2*1=2
# 2*2=4
# 2*3=6
# 2*4=8
# 2*5=10
# 2*6=12
# 2*7=14
# 2*8=16
# 2*9=18
# 2*10=20

# %% [markdown]
# Break statement

# %%
num=input("enter the number you want to print")
num=int(num)
i=0
while(i<=10):
  print(f"{num}*{i}={num*i}")
  if(i==5):
   break
  i=i+1
# Out:
# enter the number you want to print10
# 10*0=0
# 10*1=10
# 10*2=20
# 10*3=30
# 10*4=40
# 10*5=50

# %%
List_of_Book=["Python", "Java", "C", "C++"]
Book=input("enter book you want in library")
Book_no=0 #Start from index 0
while(Book_no<len(List_of_Book)):
  if(Book==List_of_Book[Book_no]):
   print("Yes, Book is available")
   break
  Book_no=Book_no+1
# Out:
# enter book you want in libraryC
# Yes, Book is available

# %% [markdown]
# while-else

# %%
List_of_Book=["Python", "Java", "C", "C++"]
Book=input("enter book you want in library")
Book_no=0 #Start from index 0
while(Book_no<len(List_of_Book)):
  if(Book==List_of_Book[Book_no]):
   print("Yes, Book is available")
   break
  Book_no=Book_no+1
else:
  print("Book is not available")
# Out:
# enter book you want in libraryC+
# Book is not available

# %% [markdown]
# Nested While loop

# %%
i=2
while(i<=5):
  print(f"{i} table")
  j=1
  while(j<=10):
    print(f"{i}*{j}={i*j}")
    j=j+1
  i=i+1
# Out:
# 2 table
# 2*1=2
# 2*2=4
# 2*3=6
# 2*4=8
# 2*5=10
# 2*6=12
# 2*7=14
# 2*8=16
# 2*9=18
# 2*10=20
# 3 table
# 3*1=3
# 3*2=6
# 3*3=9
# 3*4=12
# 3*5=15
# 3*6=18
# 3*7=21
# 3*8=24
# 3*9=27
# 3*10=30
# 4 table
# 4*1=4
# 4*2=8
# 4*3=12
# 4*4=16
# 4*5=20
# 4*6=24
# 4*7=28
# 4*8=32
# 4*9=36
# 4*10=40
# 5 table
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50

# %% [markdown]
# For and in loop

# %%
print(list(range(5)))
# Out:
# [0, 1, 2, 3, 4]

# %%
print(list(range(2,10)))
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]

# %%
print(list(range(2, 10, 2)))
# Out:
# [2, 4, 6, 8]

# %%
print(list(range(10, 2, -2)))
# Out:
# [10, 8, 6, 4]

# %%
for i in range(5):
  print("Welcome Sanketa")
# Out:
# Welcome Sanketa
# Welcome Sanketa
# Welcome Sanketa
# Welcome Sanketa
# Welcome Sanketa

# %%
for i in range(3):
  print("Welcome Sanketa")
  print("i=",i)
# Out:
# Welcome Sanketa
# i= 0
# Welcome Sanketa
# i= 1
# Welcome Sanketa
# i= 2

# %% [markdown]
# Print number table

# %%
num=input("enter the number you want to print")
num=int(num)
for i in range (1,10):
 print(f"{num}*{i}={num*i}")
# Out:
# enter the number you want to print1
# 1*1=1
# 1*2=2
# 1*3=3
# 1*4=4
# 1*5=5
# 1*6=6
# 1*7=7
# 1*8=8
# 1*9=9

# %%
num=input("enter the number you want to print")
num=int(num)
for i in range (10):
 print(f"{num}*{i}={num*i}")
# Out:
# enter the number you want to print3
# 3*0=0
# 3*1=3
# 3*2=6
# 3*3=9
# 3*4=12
# 3*5=15
# 3*6=18
# 3*7=21
# 3*8=24
# 3*9=27

# %%
for i in range (5):
 print("A"*(i+1))
# Out:
# A
# AA
# AAA
# AAAA
# AAAAA

# %% [markdown]
# For loop with break statement

# %%
List_of_Book=["Python", "Java", "C", "C++"]
Book=input("enter book you want in library")
for Book_no in range(len(List_of_Book)):
  if(Book==List_of_Book[Book_no]):
   print("Yes, available")
   break
# Out:
# enter book you want in libraryC
# Yes, available

# %%
List_of_Book=["Python", "Java", "C", "C++"]
Book=input("enter book you want in library")
for Book_no in range(len(List_of_Book)):
  if(Book==List_of_Book[Book_no]):
   print("Yes, available")
   break
print("Book_no=",Book_no)
# Out:
# enter book you want in libraryC
# Yes, available
# Book_no= 2

# %% [markdown]
# For loop with continue statement

# %%
for i in range (5):
  if(i==2):
    continue
  print("i=",i)
# Out:
# i= 0
# i= 1
# i= 3
# i= 4

# %% [markdown]
# Nested for loop

# %%
for i in range(5):
  for j in range(i+1):
    print("*", end=" ")
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# Break statement

# %%
for i in range (4):
 for j in range (3):
   if (i!=j):
     print(i,j)
 print("====")
# Out:
# 0 1
# 0 2
# ====
# 1 0
# 1 2
# ====
# 2 0
# 2 1
# ====
# 3 0
# 3 1
# 3 2
# ====

# %% [markdown]
# Break statement (Inner for loop)

# %%
for i in range (4):
 for j in range (3):
   if (i!=j):
     print(i,j)
     break
 print("====")
# Out:
# 0 1
# ====
# 1 0
# ====
# 2 0
# ====
# 3 0
# ====

# %%
for i in range (4):
 for j in range (3):
   if (i!=j):
     print(i,j)
 print("====")
# Out:
# 0 1
# 0 2
# ====
# 1 0
# 1 2
# ====
# 2 0
# 2 1
# ====
# 3 0
# 3 1
# 3 2
# ====

# %%
for i in range (4):
 for j in range (3):
   if (i!=j):
     print(i,j)
 if (i==2):
  break
 print("====")
# Out:
# 0 1
# 0 2
# ====
# 1 0
# 1 2
# ====
# 2 0
# 2 1

# %% [markdown]
# Day-5

# %% [markdown]
# String Processing

# %% [markdown]
# Single Line

# %%
name="Sanketa Jena"
location="Badamba"
print("name")
print("location")
# Out:
# name
# location

# %% [markdown]
# Multiple line

# %% [markdown]
# Positive, negative and index error

# %%
def name_age():
  print("sanketajena")
  print("age=42")

# %%
name_age()
# Out:
# sanketajena
# age=42

# %%
def add(a,b):
  addition=a+b
  return addition

# %%
a=input("enter a value")
b=input("enter b value")
a=int(a)
b=int(b)
k=add(a,b)
print("sum=",k)
# Out:
# enter a value2
# enter b value3
# sum= 5

# %%
def res(units):
  total_price=units*2
  return total_price
def com(units):ust_type=input
  total_price=units*5
  return total_price
def ind(units):
  total_price=units*10
  return total_price

# %%
units=input("enter no. of units consumed")
cust_type=input("type of customer: resi, com, ind")
units=int(units)
if(cust_type=="resi"):
  print(f"total price={res(units)}")
elif(cust_type=="com"):
  print(f"total price={com(units)}")
elif(cust_type=="ind"):
  print(f"total price={com(ind)}")
# Out:
# enter no. of units consumed3
# type of customer: resi, com, indresi
# total price=6

# %% [markdown]
# 19-9-2026

# %% [markdown]
# Package

# %% [markdown]
# Mypack
